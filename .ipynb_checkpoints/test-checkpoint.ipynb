# %%
from nuscenes.nuscenes import NuScenes
from nuscenes.nuscenes import NuScenesExplorer
# import tensorflow as tf
import cv2
import numpy as np
from nuscenes.image_utils import ImageProcessing as ip


root = 'D:/dataset/v1.0-mini'
nusc = NuScenes(version='v1.0-mini', dataroot=root, verbose=True)


# get night scenes
night_scene = nusc.list_night()


my_sample = nusc.sample[0]
nusc.render_sample_data(my_sample['data']['CAM_FRONT'])
# Out:
# ======
# Loading NuScenes tables for version v1.0-mini ...
# 23 category,
# 8 attribute,
# 4 visibility,
# 911 instance,
# 12 sensor,
# 120 calibrated_sensor,
# 31206 ego_pose,
# 8 log,
# 10 scene,
# 404 sample,
# 31206 sample_data,
# 18538 sample_annotation,
# 4 map,
# Done loading in 1.0 seconds.
# ======
# Reverse indexing ...
# Done reverse indexing in 0.2 seconds.
# ======

# %%
# sensor_token = nusc.get_sensor_token_list(night_scene[0])
sensor_token = 'e3d495d4ac534d54b321f50006683844'
im = ip(sensor_token, nusc, min_size=900)
# Render ground truth
im.render_arbitrary()

# %%
# Render prediction
im.render_rectangle(im.control_points_list)
